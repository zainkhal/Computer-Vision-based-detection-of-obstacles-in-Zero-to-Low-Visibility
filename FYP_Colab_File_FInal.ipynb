# %% [markdown]
# Name: Zain Khalid, Ali Shahid, Abdullah ALi
#
# Roll-No: 22I-2161, 22I-2199, 22I-2153
#
# Project: "Autonomous Vehicle Obstacle Detection "

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
#  22I_2194A.ipynb
#  Copy_of_CS441_HW1_Starter_ALI.ipynb
# 'Copy of CS441_HW1_Starter.ipynb'
# 'Copy of CS441_HW2_Starter.ipynb'
# 'Copy of Lab_01_Introduction_to_Pyton.ipynb'
#  Copy_of_Lab09_support_vector_machine_for_classification.ipynb
# 'Copy of Welcome to Colab'
# 'CS441_HW2_Starter_(1) (1).ipynb'
#  i202453_AML_Assignment_2.ipynb
#  i222153_CS441_HW2_Starter.ipynb
#  i229855_mustafa_Lab_11_Unsupervised_Learning_Clustering_and_Cluster_Analysis_using_Python.ipynb
#  L12_NaiveBayes.ipynb
#  Lab_01_Introduction_to_Pyton.ipynb
#  Lab01.ipynb
# 'Lab_02_Python_for_ML (1).ipynb'
# 'Lab_02_Python_for_ML (2).ipynb'
#  Lab_02_Python_for_ML.ipynb
#  Lab_03_Numpy.ipynb
#  Lab_04_Intro_to_ML.ipynb
#  Lab07_Tree_Based_Models_in_ML_using_Python.ipynb
#  Lab09_support_vector_machine_for_classification.ipynb
#  Lab_10_Dimensionality_Reduction_in_Python.ipynb
#  Lab_11_Unsupervised_Learning_Clustering_and_Cluster_Analysis_using_Python.ipynb
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="cAEb5cosFgHjs3dfjrAH")
project = rf.workspace("aaz").project("low-visibility-final-bg938")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(
    data='/content/drive/MyDrive/Colab Notebooks/low-visibility-Final-1/data.yaml', # Corrected: point to data.yaml
    epochs=50, # total epochs
    save_period=5, # save every 5 epochs
    project='runs/train', # where to save runs
    name='yolov8n_custom', # name of the run
)
# Out:
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
M = YOLO("/content/drive/MyDrive/Colab Notebooks/runs/train/yolov8n_custom4/weights/best.pt")
M.predict("/content/drive/MyDrive/Colab Notebooks/low-visibility-Final-1/test/images/A-D-9_jpg.rf.fda7cf89995c58044b478e68f782bbd0.jpg", save = True)
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/low-visibility-Final-1/test/images/A-D-9_jpg.rf.fda7cf89995c58044b478e68f782bbd0.jpg: 640x640 (no detections), 7.3ms
# Speed: 1.7ms preprocess, 7.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/drive/MyDrive/Colab Notebooks/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bike', 1: 'Car', 2: 'Person'}
#  obb: None
#  orig_img: array([[[194, 198, 186],
#          [196, 200, 188],
#          [198, 202, 190],
#          ...,
#          [172, 178, 173],
#          [165, 171, 166],
#          [194, 200, 195]],
#
#         [[193, 197, 185],
#          [195, 199, 187],
#          [196, 200, 188],
#          ...,
#          [161, 167, 162],
#          [157, 163, 158],
#          [172, 178, 173]],
#
#         [[193, 197, 185],
#          [195, 199, 187],
# ...
